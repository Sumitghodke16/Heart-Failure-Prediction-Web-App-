# %%
print("hello world")
# Out:
# Running cells with 'myenv (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n myenv ipykernel --update-deps --force-reinstall'
